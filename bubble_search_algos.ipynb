# %% [markdown]
# <a href="https://colab.research.google.com/github/will001-art-ke/WILL/blob/main/bubble_search_algos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from will_utils import report_search

my_list = list(range(10))

report_search(my_list, 7)
report_search(my_list, 10)
# Out:
# Element 7 found at index 7
# Element 10 not found in the list
# -1

# %%
from will_utils import report_search

my_list = list(range(100))

report_search(my_list, 79)
report_search(my_list, 100)
# Out:
# Element 79 found at index 79
# Element 100 not found in the list
# -1

# %%
from will_utils import report_search

my_list = list(range(1000))

report_search(my_list, 778)
report_search(my_list, 1000)
# Out:
# Element 778 found at index 778
# Element 1000 not found in the list
# -1

# %%
from will_utils import report_search

my_list = list(range(10000))

report_search(my_list, 7234)
report_search(my_list, 1000)
# Out:
# Element 7234 found at index 7234
# Element 1000 found at index 1000
# 1000

# %%
import random

from will_utils import bubble_sort

random_list = [random.randint(0, 10) for _ in range(10)]

print("Original list (first 10 elements):", random_list[:10])

sorted_list = bubble_sort(random_list)

print("Sorted list (first 10 elements):", sorted_list[:10])
print("Sorted list (last 10 elements):", sorted_list[-10:])
# Out:
# Original list (first 10 elements): [7, 2, 2, 10, 0, 8, 8, 7, 8, 3]
# Sorted list (first 10 elements): [0, 2, 2, 3, 7, 7, 8, 8, 8, 10]
# Sorted list (last 10 elements): [0, 2, 2, 3, 7, 7, 8, 8, 8, 10]

# %%
import random

from will_utils import bubble_sort

random_list = [random.randint(0, 100) for _ in range(100)]

print("Original list (first 10 elements):", random_list[:10])

sorted_list = bubble_sort(random_list)

print("Sorted list (first 10 elements):", sorted_list[:10])
print("Sorted list (last 10 elements):", sorted_list[-10:])
# Out:
# Original list (first 10 elements): [16, 51, 84, 67, 82, 61, 7, 75, 77, 43]
# Sorted list (first 10 elements): [0, 1, 1, 4, 4, 6, 7, 7, 9, 10]
# Sorted list (last 10 elements): [83, 84, 86, 88, 88, 90, 97, 98, 99, 100]

# %%
import random

from will_utils import bubble_sort

random_list = [random.randint(0, 100) for _ in range(100)]

print("Original list (first 10 elements):", random_list[:10])

sorted_list = bubble_sort(random_list)

print("Sorted list (first 10 elements):", sorted_list[:10])
print("Sorted list (last 10 elements):", sorted_list[-10:])
# Out:
# Original list (first 10 elements): [66, 72, 33, 86, 23, 19, 78, 37, 35, 6]
# Sorted list (first 10 elements): [1, 2, 2, 5, 5, 6, 8, 10, 13, 13]
# Sorted list (last 10 elements): [90, 91, 91, 92, 93, 95, 95, 95, 96, 99]

# %%
import random

from will_utils import bubble_sort

random_list = [random.randint(0, 1000) for _ in range(1000)]

print("Original list (first 10 elements):", random_list[:10])

sorted_list = bubble_sort(random_list)

print("Sorted list (first 10 elements):", sorted_list[:10])
print("Sorted list (last 10 elements):", sorted_list[-10:])
# Out:
# Original list (first 10 elements): [7, 938, 236, 411, 206, 44, 480, 993, 868, 457]
# Sorted list (first 10 elements): [0, 0, 1, 2, 2, 5, 7, 7, 7, 9]
# Sorted list (last 10 elements): [988, 989, 991, 993, 993, 995, 996, 997, 1000, 1000]

# %%
import random

from will_utils import bubble_sort

random_list = [random.randint(0, 10000) for _ in range(10000)]

print("Original list (first 10 elements):", random_list[:10])

sorted_list = bubble_sort(random_list)

print("Sorted list (first 10 elements):", sorted_list[:10])
print("Sorted list (last 10 elements):", sorted_list[-10:])
# Out:
# Original list (first 10 elements): [9498, 6577, 4150, 5200, 1871, 215, 2051, 4304, 6200, 8570]
# Sorted list (first 10 elements): [1, 2, 2, 5, 7, 8, 9, 9, 9, 10]
# Sorted list (last 10 elements): [9985, 9985, 9987, 9988, 9992, 9993, 9993, 9994, 9995, 9995]
